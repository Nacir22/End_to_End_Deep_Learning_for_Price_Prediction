# %%
# %cd /content/drive/MyDrive/End_to_End_Deep_Learning_for_Price_Prediction/notebooks
# Out:
# /content/drive/MyDrive/End-to-End-Deep-Learning-for-Price-Prediction/notebooks

# %%
import os
import yaml
import pandas as pandas

# %%
current_path = os.getcwd()
                                   #1
path_to_yaml = os.path.join(current_path,   'data_exploration_config.yml')                     #2

try:
    with open (path_to_yaml, 'r') as c_file:
        config = yaml.safe_load(c_file)                           #3
except Exception as e:
    print('Error reading the config file')

load_from_scratch = config['general']['load_from_scratch']        #4
save_raw_dataframe = config['general']['save_raw_dataframe']
save_transformed_dataframe = config['general']['save_transformed_dataframe']
remove_bad_values = config['general']['remove_bad_values']


input_csv = config['file_names']['input_csv']
pickled_input_dataframe = config['file_names']['pickled_input_dataframe']
pickled_output_dataframe = config['file_names']['pickled_output_dataframe']


categorical_columns = config['columns']['categorical']

continuous_columns = config['columns']['continuous']
data_columns = config['columns']['date']
text_columns = config['columns']['text']
excluded_columns = config['columns']['excluded']

max_long = config['bounding_box']['max_long']
max_lat = config['bounding_box']['max_lat']
min_long = config['bounding_box']['min_long']
min_lat = config['bounding_box']['min_lat']

newark_max_long = config['newark_bounding_box']['max_long']
newark_max_long = config['newark_bounding_box']['max_lat']
newark_max_long = config['newark_bounding_box']['min_long']
newark_max_long = config['newark_bounding_box']['min_lat']

geo_columns =  config['geo_columns']

# %%
def get_path():                                                           #1
    rawpath = os.getcwd()
    path = os.path.abspath(os.path.join(rawpath, '..', 'data'))
    return(path)

import pandas as pd                                                       #2
path = get_path()

df = pd.read_csv(os.path.join(path,input_csv))

df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
# Count missing values for each column
missing_values_count = df.isnull().sum()

print(missing_values_count)
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
continuous_columns
# Out:
# ['minimum_nights',
#  'number_of_reviews',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'latitude',
#  'longitude']

# %%
for column in continuous_columns[:4]:

  invalid_count = df[(df[column] < 0)] .shape[0]

  print(f"Invalid {column} Count: {invalid_count}")
# Out:
# Invalid minimum_nights Count: 0
# Invalid number_of_reviews Count: 0
# Invalid reviews_per_month Count: 0
# Invalid calculated_host_listings_count Count: 0

# %%
latitude = geo_columns[0]
longitude = geo_columns[1]

# Identify rows where latitude or longitude values fall outside the city's valid range
invalid_location = (
    (df['latitude'] < min_lat) | (df['latitude'] > max_lat) |
    (df['longitude'] < min_long) | (df['longitude'] > max_long)
)


# Count of invalid location entries
invalid_location_count = df[invalid_location].shape[0]

print(f"Invalid Location Count: {invalid_location_count}")
# Out:
# Invalid Location Count: 0

# %%
# Use nunique to get the number of unique values in each categorical column
unique_values_count = df[categorical_columns].nunique()

print(unique_values_count)
# Out:
# neighbourhood_group      5
# neighbourhood          221
# room_type                3
# dtype: int64

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/End_to_End_Deep_Learning_for_Price_Prediction/notebooks'

# %%
# Save the DataFrame to a pickle file
rawpath = os.getcwd()
path = os.path.abspath(os.path.join(rawpath, '..', 'pickle'))

saved_pickle_path = os.path.join(path, pickled_output_dataframe)
df.to_pickle(saved_pickle_path)

print("DataFrame saved as pickle file.")
# Out:
# DataFrame saved as pickle file.

# %%
path
# Out:
# '/content/drive/MyDrive/End_to_End_Deep_Learning_for_Price_Prediction/data'
